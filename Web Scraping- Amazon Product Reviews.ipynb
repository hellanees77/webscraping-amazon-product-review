# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link = 'https://www.amazon.com/2022-Apple-MacBook-Laptop-chip/dp/B0B3C5HNXJ/ref=sr_1_1_mod_primary_new?crid=PTL44QSSFSX0&dib=eyJ2IjoiMSJ9.-u490ua9N7zRU3m3CTsdPtb7w2r3owg0mztDpq6yvMOpn8gjumU2sEWZajzhRPpNCveXFM5JkqcS3eTIVl9dYdNWf4MHdjpD8Hpmm3Sh4XcowaofcP28h_eaMTD8bDGh529ZL6zProJ-p8XC1UUa5w.C0t6UCRcOMjQifiymFcesEdjqcs1IMF3Q1eSvmj7rTs&dib_tag=se&keywords=macbook%2Bpro&qid=1705129634&sprefix=mac%2Caps%2C500&sr=8-1&th=1'

# %%
page = requests.get(link)

# %%
page

# %%
page.content

# %%
soup = bs(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link crossorigin="" href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://images-na.ssl-images-amazon.com" rel="preconnect"/>
#   <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
#   <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# ...

# %%
names = s oup.find_all('span',class_='a-profile-name')

# %%
len(names)
# Out:
# 17

# %%
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())

# %%
cust_name
# Out:
# ['AppleCare+ for Mac',
#  'Amazon Customer',
#  'Awesome Dude!',
#  'Amy',
#  'Jean Gallahar',
#  'Eucalyptus Gold',
#  'Michael B. Casey',
#  'Jo',
#  'Jenn Szer',
#  'gab',
#  'gab',
#  'L Ma',
#  'Sheckler',
#  'Sheckler',
#  'Jeffrey Loewen',
#  'Please try a different name',
#  'Agustin']

# %%
cust_name.remove('gab')

# %%
cust_name
# Out:
# ['AppleCare+ for Mac',
#  'Amazon Customer',
#  'Awesome Dude!',
#  'Amy',
#  'Jean Gallahar',
#  'Eucalyptus Gold',
#  'Michael B. Casey',
#  'Jo',
#  'Jenn Szer',
#  'gab',
#  'L Ma',
#  'Sheckler',
#  'Sheckler',
#  'Jeffrey Loewen',
#  'Please try a different name',
#  'Agustin']

# %%
cust_name.remove('Sheckler')

# %%
cust_name
# Out:
# ['AppleCare+ for Mac',
#  'Amazon Customer',
#  'Awesome Dude!',
#  'Amy',
#  'Jean Gallahar',
#  'Eucalyptus Gold',
#  'Michael B. Casey',
#  'Jo',
#  'Jenn Szer',
#  'gab',
#  'L Ma',
#  'Sheckler',
#  'Jeffrey Loewen',
#  'Please try a different name',
#  'Agustin']

# %%
title = soup.find_all(class_='review-title-content')

# %%
title
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3M47CUP3P1S7I?ASIN=B0B3C5HNXJ"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
#  <span>Impressive Performance and Sleek Design - My Experience with the M2 MacBook Pro 13 Inch!</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R1UBYV7U9OZYL0?ASIN=B0B3C5HNXJ"><i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i><span class="a-letter-space"></span>
#  <span>Awesome price, with the investment</span>
#  </a>,
# ...

# %%
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())
review_title
# Out:
# ['5.0 out of 5 stars\nImpressive Performance and Sleek Design - My Experience with the M2 MacBook Pro 13 Inch!\n',
#  '5.0 out of 5 stars\nAwesome price, with the investment\n',
#  '5.0 out of 5 stars\nGreat price! Great product!\n',
#  '5.0 out of 5 stars\nI mean, it’s a Mac. You can’t go wrong\n',
#  '5.0 out of 5 stars\nGranddaughter Loves it\n',
#  '4.0 out of 5 stars\nEasy, fast, light, and slim\n',
#  '5.0 out of 5 stars\nworks great\n',
#  '5.0 out of 5 stars\nLlegó perfecta\n',
#  '\ngreat product\n',
#  '\nSo Worth the upgrade\n',
#  '\nCan’t beat a Mac!\n',
#  '\nGreat\n',
#  '\nMacbook\n']

# %%
review_title[:] = [titles.lstrip('\n') for titles in review_title]
review_title
# Out:
# ['5.0 out of 5 stars\nImpressive Performance and Sleek Design - My Experience with the M2 MacBook Pro 13 Inch!\n',
#  '5.0 out of 5 stars\nAwesome price, with the investment\n',
#  '5.0 out of 5 stars\nGreat price! Great product!\n',
#  '5.0 out of 5 stars\nI mean, it’s a Mac. You can’t go wrong\n',
#  '5.0 out of 5 stars\nGranddaughter Loves it\n',
#  '4.0 out of 5 stars\nEasy, fast, light, and slim\n',
#  '5.0 out of 5 stars\nworks great\n',
#  '5.0 out of 5 stars\nLlegó perfecta\n',
#  'great product\n',
#  'So Worth the upgrade\n',
#  'Can’t beat a Mac!\n',
#  'Great\n',
#  'Macbook\n']

# %%
review_title[:] = [titles.rstrip('\n') for titles in review_title]
review_title
# Out:
# ['5.0 out of 5 stars\nImpressive Performance and Sleek Design - My Experience with the M2 MacBook Pro 13 Inch!',
#  '5.0 out of 5 stars\nAwesome price, with the investment',
#  '5.0 out of 5 stars\nGreat price! Great product!',
#  '5.0 out of 5 stars\nI mean, it’s a Mac. You can’t go wrong',
#  '5.0 out of 5 stars\nGranddaughter Loves it',
#  '4.0 out of 5 stars\nEasy, fast, light, and slim',
#  '5.0 out of 5 stars\nworks great',
#  '5.0 out of 5 stars\nLlegó perfecta',
#  'great product',
#  'So Worth the upgrade',
#  'Can’t beat a Mac!',
#  'Great',
#  'Macbook']

# %%
rating = soup.find_all('i',class_='review-rating')
rating
# Out:
# [<i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
# ...

# %%
rate = []
for i in range(0,len(rating)):
    rate.append(rating[i].get_text())
rate
# Out:
# ['5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '5.0 out of 5 stars']

# %%
len(rate)
# Out:
# 13

# %%
review = soup.find_all("span",{"data-hook":"review-body"})
review
# Out:
# [<span class="a-size-base review-text" data-hook="review-body"><div class="a-expander-collapsed-height a-row a-expander-container a-expander-partial-collapse-container" data-a-expander-collapsed-height="300" data-a-expander-name="review_text_read_more" style="max-height:300px"><div aria-expanded="false" class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content" data-hook="review-collapsed">
# ...

# %%
review_content = []
for i in range(0,len(review)):
    review_content.append(review[i].get_text())
review_content
# Out:
# ["\nI recently made the decision to upgrade my laptop, and after much research and anticipation, I finally got my hands on the M2 MacBook Pro 13 Inch – and let me tell you, it's been an cutie!From the moment I opened the sleek packaging, I was captivated by the elegant design of the laptop. The slim profile, premium build quality, and the iconic Apple logo gave me an instant sense of satisfaction. But the real magic began when I powered it on.The performance of the M2 chip truly left me in awe. Apps launch almost instantly, and multitasking feels seamless. Whether I'm running resource-intensive software, editing high-resolution photos, or streaming 4K videos, the laptop handles it all effortlessly. The speed and responsiveness of this machine have undoubtedly boosted my productivity and allowed me to breeze through my tasks.The Retina display is a visual feast for the eyes. The vibrant colors, deep blacks, and sharp details make every piece of content look stunning. Whether I'm worki
# ...

# %%
review_content[:] = [reviews.lstrip('\n') for reviews in review_content]
review_content
# Out:
# ["I recently made the decision to upgrade my laptop, and after much research and anticipation, I finally got my hands on the M2 MacBook Pro 13 Inch – and let me tell you, it's been an cutie!From the moment I opened the sleek packaging, I was captivated by the elegant design of the laptop. The slim profile, premium build quality, and the iconic Apple logo gave me an instant sense of satisfaction. But the real magic began when I powered it on.The performance of the M2 chip truly left me in awe. Apps launch almost instantly, and multitasking feels seamless. Whether I'm running resource-intensive software, editing high-resolution photos, or streaming 4K videos, the laptop handles it all effortlessly. The speed and responsiveness of this machine have undoubtedly boosted my productivity and allowed me to breeze through my tasks.The Retina display is a visual feast for the eyes. The vibrant colors, deep blacks, and sharp details make every piece of content look stunning. Whether I'm working
# ...

# %%
review_content[:] = [reviews.rstrip('\n') for reviews in review_content]
review_content
# Out:
# ["I recently made the decision to upgrade my laptop, and after much research and anticipation, I finally got my hands on the M2 MacBook Pro 13 Inch – and let me tell you, it's been an cutie!From the moment I opened the sleek packaging, I was captivated by the elegant design of the laptop. The slim profile, premium build quality, and the iconic Apple logo gave me an instant sense of satisfaction. But the real magic began when I powered it on.The performance of the M2 chip truly left me in awe. Apps launch almost instantly, and multitasking feels seamless. Whether I'm running resource-intensive software, editing high-resolution photos, or streaming 4K videos, the laptop handles it all effortlessly. The speed and responsiveness of this machine have undoubtedly boosted my productivity and allowed me to breeze through my tasks.The Retina display is a visual feast for the eyes. The vibrant colors, deep blacks, and sharp details make every piece of content look stunning. Whether I'm working
# ...

# %%
len(review_content)
# Out:
# 13

# %%
cust_name
review_title
rate
review_content
# Out:
# ["I recently made the decision to upgrade my laptop, and after much research and anticipation, I finally got my hands on the M2 MacBook Pro 13 Inch – and let me tell you, it's been an cutie!From the moment I opened the sleek packaging, I was captivated by the elegant design of the laptop. The slim profile, premium build quality, and the iconic Apple logo gave me an instant sense of satisfaction. But the real magic began when I powered it on.The performance of the M2 chip truly left me in awe. Apps launch almost instantly, and multitasking feels seamless. Whether I'm running resource-intensive software, editing high-resolution photos, or streaming 4K videos, the laptop handles it all effortlessly. The speed and responsiveness of this machine have undoubtedly boosted my productivity and allowed me to breeze through my tasks.The Retina display is a visual feast for the eyes. The vibrant colors, deep blacks, and sharp details make every piece of content look stunning. Whether I'm working
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(list(zip(cust_name,review_title,rate,review_content)), columns=["Customer Name","Review Title","Rates","Review Content"])

# %%
df
# Out:
#          Customer Name                                       Review Title  \
# 0   AppleCare+ for Mac  5.0 out of 5 stars\nImpressive Performance and...
# 1      Amazon Customer  5.0 out of 5 stars\nAwesome price, with the in...
# 2        Awesome Dude!    5.0 out of 5 stars\nGreat price! Great product!
# 3                  Amy  5.0 out of 5 stars\nI mean, it’s a Mac. You ca...
# 4        Jean Gallahar         5.0 out of 5 stars\nGranddaughter Loves it
# 5      Eucalyptus Gold    4.0 out of 5 stars\nEasy, fast, light, and slim
# 6     Michael B. Casey                    5.0 out of 5 stars\nworks great
# 7                   Jo                 5.0 out of 5 stars\nLlegó perfecta
# 8            Jenn Szer                                      great product
# 9                  gab                               So Worth the upgrade
# 10                L Ma                                  Can’t beat a Mac!
# 11            Sheckler                                              Great
# ...

# %%
df.to_csv('/Users/anishshrestha/Downloads/products.csv',index=True, header=False)
